# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
import pickle
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load the trained model , scalar and pickle

# %%
model=load_model('model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
## load the encoder and scaler

# %%
with open("label_encoder_gender.pkl","rb") as file:
    label_encoder_geo=pickle.load(file)
    
with open("one_hot_encoder.pkl","rb") as file:
    label_encoder_gender=pickle.load(file)
with open('Scaler.pkl','rb') as file:
    scaler=pickle.load(file)

# %%
### Excute input data

# %%
# Example input data
input_data = {
    'CreditScore': 600,
    'Geography': 'France',
    'Gender': 'Male',
    'Age': 40,
    'Tenure': 3,
    'Balance': 60000,
    'NumOfProducts': 2,
    'HasCrCard': 1,
    'IsActiveMember': 1,
    'EstimatedSalary': 50000
}

# %%
input_df=pd.DataFrame([input_data])
input_df
# Out:
#    CreditScore Geography Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          600    France   Male   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1            50000

# %%
## One hot encode 'Geography'

# %%
geo_encoded=label_encoder_gender.transform([[input_data['Geography']]]).toarray()
geo_encoded_df=pd.DataFrame(geo_encoded,columns=label_encoder_gender.get_feature_names_out(['Geography']))
# Out:
# d:\GLOBAL_VENV\global_venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
geo_encoded_df
# Out:
#    Geography_France  Geography_Germany  Geography_Spain
# 0               1.0                0.0              0.0

# %%
input_data=pd.concat([input_df,geo_encoded_df],axis=1)
input_data
# Out:
#    CreditScore Geography Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          600    France   Male   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Geography_France  \
# 0          1               1            50000               1.0
#
#    Geography_Germany  Geography_Spain
# 0                0.0              0.0

# %%
## Encode my categorical variables

# %%
input_data["Gender"]=label_encoder_geo.transform(input_data["Gender"])

# %%
input_data
# Out:
#    CreditScore Geography  Gender  Age  Tenure  Balance  NumOfProducts  \
# 0          600    France       1   40       3    60000              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Geography_France  \
# 0          1               1            50000               1.0
#
#    Geography_Germany  Geography_Spain
# 0                0.0              0.0

# %%
input_data.drop("Geography",axis=1,inplace=True)

# %%
input_data
# Out:
#    CreditScore  Gender  Age  Tenure  Balance  NumOfProducts  HasCrCard  \
# 0          600       1   40       3    60000              2          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               1            50000               1.0                0.0
#
#    Geography_Spain
# 0              0.0

# %%
## Scaling the input data

# %%
input_scaled=scaler.transform(input_data)
input_scaled
# Out:
# array([[-0.53598516,  0.91324755,  0.10479359, -0.69539349, -0.25781119,
#          0.80843615,  0.64920267,  0.97481699, -0.87683221,  1.00150113,
#         -0.57946723, -0.57638802]])

# %%
## Now prediction
prediction=model.predict(input_scaled)
prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# array([[0.04606771]], dtype=float32)

# %%
prediction_probab=prediction[0][0]
prediction
# Out:
# array([[0.04606771]], dtype=float32)
